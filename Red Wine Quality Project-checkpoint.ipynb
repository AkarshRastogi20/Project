# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df= pd.read_csv('wine-quality-red.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.shape
# Out:
# (1599, 12)

# %% [markdown]
# Here we have 1599 rows and 12 columns in the dataset

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# Summary Statistics

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# now here we can see that
#
# -> there is large difference in 75% percentile and max in residual sugar, free sulfur dioxide, total sulfur dioxide 1 and 2 observation suggest that there are extreme outliers are present in these three columns

# %% [markdown]
# ## Exploring Data Variables

# %%
df.quality.unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
df.quality.value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
#to check missing values
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# dataset has no missing values if there are missing values it would be in different colors

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# to check correlation
dfcor=df.corr()
dfcor
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(dfcor,cmap='Blues', annot=True, linewidth=.3)
# Out:
# <AxesSubplot:>

# %% [markdown]
# so here the observation is that the dark shades are highly correlated.

# %%
dfcor['quality']
# Out:
# fixed acidity           0.124052
# volatile acidity       -0.390558
# citric acid             0.226373
# residual sugar          0.013732
# chlorides              -0.128907
# free sulfur dioxide    -0.050656
# total sulfur dioxide   -0.185100
# density                -0.174919
# pH                     -0.057731
# sulphates               0.251397
# alcohol                 0.476166
# quality                 1.000000
# Name: quality, dtype: float64

# %%
sns.countplot(df['quality'])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %% [markdown]
# Here we can see that most of the samples of wine around 600 to 700 relay in no 5 & 6 and around 200 in no 7 and more which is count as good wine so whole model will bias to these three quality no(will treat in imbalance data)

# %%
sns.barplot(x='quality', y='fixed acidity', linewidth=2.5, errcolor='.2', data=df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='fixed acidity'>

# %% [markdown]
# we can see here that fixed acidity is almost common in all the samples of wine which means it doesn't affect the quality of wine that much.

# %%
sns.barplot(x='quality', y='volatile acidity', linewidth=2.5, errcolor='.2', edgecolor='.2', data=df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='volatile acidity'>

# %% [markdown]
# so we notice here that less volatile acidity imporves the wine quality

# %%
sns.barplot(x='quality', y='citric acid', linewidth=2.5, errcolor='.2', edgecolor='.2', data=df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='citric acid'>

# %% [markdown]
# Here citric acid has a huge impact on quality of wine, increasing citric acid also imporves the quality of wine.

# %%
sns.barplot(x='quality', y='residual sugar', linewidth=2.5, errcolor='.2', edgecolor='.2', data=df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='residual sugar'>

# %% [markdown]
# there is no huge impact of residual sugar on quality of wine it's almost common in all qualities.

# %%
sns.barplot(x='quality', y='chlorides', linewidth=2.5, errcolor='.2', edgecolor='.2', data=df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='chlorides'>

# %% [markdown]
# we notice here chlorides has a litle impact on quality if it decrease that improves little of wine quality.

# %%
sns.barplot(x='quality', y='free sulfur dioxide', linewidth=2.5, errcolor='.2', edgecolor='.2', data=df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='free sulfur dioxide'>

# %%
sns.barplot(x='quality', y='total sulfur dioxide', linewidth=2.5, errcolor='.2', edgecolor='.2', data=df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='total sulfur dioxide'>

# %% [markdown]
# in above both cell total sulfur dioxide and free sulfur dioxide having both kind of impact on quality positive and negative.

# %%
sns.barplot(x='quality', y='density', linewidth=2.5, errcolor='.2', edgecolor='.2', data=df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='density'>

# %% [markdown]
# there is no relation between density and quality.

# %%
sns.barplot(x='quality', y='pH', linewidth=2.5, errcolor='.2', edgecolor='.2', data=df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='pH'>

# %% [markdown]
# there is no huge relation between pH and quality as well, there is very minor effect.

# %%
sns.barplot(x='quality', y='sulphates', linewidth=2.5, errcolor='.2', edgecolor='.2', data=df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='sulphates'>

# %% [markdown]
# here we notice sulphate improves the quality of wine

# %%
sns.barplot(x='quality', y='alcohol', linewidth=2.5, errcolor='.2', edgecolor='.2', data=df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='alcohol'>

# %% [markdown]
# there is little impact of alcohol as well on quality of wine, increasing alcohol is also improving wine quality.

# %% [markdown]
# ## Checking Outliers

# %%
plt.figure(figsize=(15,12))
for i in enumerate(df.columns):
    plt.subplot(4,3,i[0]+1)
    sns.boxplot(df[i[1]])

# %% [markdown]
# it's very easy to observe that there are almost in every column of the data set the outliers are present

# %% [markdown]
# ## To Check Distribution Of Skewness

# %%
plt.figure(figsize=(20,15))
for i in enumerate(df.columns):
    plt.subplot(4,3,i[0]+1)
    sns.distplot(df[i[1]])

# %% [markdown]
# ## Removing Outliers

# %% [markdown]
# ### zscore Method

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  13,   14,   15,   15,   17,   17,   19,   33,   38,   42,   43,
#          45,   57,   81,   81,   83,   86,   88,   91,   92,   95,  106,
#         106,  109,  120,  126,  127,  142,  144,  147,  151,  151,  151,
#         151,  163,  164,  169,  169,  181,  199,  226,  226,  240,  243,
#         244,  258,  258,  274,  281,  291,  324,  325,  339,  340,  347,
#         354,  374,  381,  391,  396,  396,  400,  400,  442,  442,  451,
#         459,  467,  480,  480,  494,  515,  517,  544,  554,  554,  555,
#         555,  557,  557,  568,  584,  588,  591,  595,  608,  614,  636,
#         639,  649,  649,  651,  652,  652,  652,  672,  672,  684,  690,
#         690,  692,  692,  695,  723,  724,  730,  754,  776,  777,  795,
#         821,  832,  836,  837,  889,  899,  911,  917,  923,  925,  926,
#         982, 1017, 1018, 1043, 1051, 1051, 1071, 1074, 1079, 1079, 1081,
#        1081, 1111, 1114, 1131, 1154, 1165, 1175, 1186, 1231, 1235, 1244,
# ...

# %%
df_1=df[(z<3).all(axis=1)]
print("With outliers::", df.shape)
print("After removing outliers::", df_1.shape)
# Out:
# With outliers:: (1599, 12)
# After removing outliers:: (1451, 12)

# %% [markdown]
# so here after removing outliers we loss 148 rows from dataset

# %% [markdown]
# ## IQR Method

# %%
from scipy import stats
IQR = stats.iqr(df)
IQR
# Out:
# 8.31

# %%
Q1 = df.quantile(0.25)
Q3 =  df.quantile(0.75)

# %%
df_out = df[~((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).any(axis=1)]
print(df_out.shape)
# Out:
# (1233, 12)

# %% [markdown]
# so after removing outliers with the help of IQR method we can notice there is huge data loss so considering zscore.

# %%
df= df_1

# %%
df.shape
# Out:
# (1451, 12)

# %% [markdown]
# ## Skewness Handling

# %%
plt.figure(figsize=(25,20))
for i in enumerate(df.columns):
    plt.subplot(3,4,i[0]+1)
    sns.distplot(df[i[1]],color='g')

# %%
df.skew()
# Out:
# fixed acidity           0.823934
# volatile acidity        0.380659
# citric acid             0.291297
# residual sugar          2.456107
# chlorides               2.275162
# free sulfur dioxide     0.869250
# total sulfur dioxide    1.183161
# density                 0.055738
# pH                      0.114705
# sulphates               0.891492
# alcohol                 0.758958
# quality                 0.407865
# dtype: float64

# %% [markdown]
# so now skewness more than +/-0.5 will we treated

# %% [markdown]
# Here we are removing skewness from fixed acidity residual sugar chlorides free sulfur dioxide total sulfur dioxide sulphates alcohol

# %% [markdown]
# Quality is target variable so will not treat that

# %%
from sklearn.preprocessing import power_transform
df[['fixed acidity','free sulfur dioxide','residual sugar','chlorides','total sulfur dioxide','sulphates','alcohol']]=power_transform(df[['fixed acidity','free sulfur dioxide','residual sugar','chlorides','total sulfur dioxide','sulphates','alcohol']])

# %%
df.skew()
# Out:
# fixed acidity           0.018666
# volatile acidity        0.380659
# citric acid             0.291297
# residual sugar         -0.004606
# chlorides              -0.114658
# free sulfur dioxide    -0.021455
# total sulfur dioxide   -0.005813
# density                 0.055738
# pH                      0.114705
# sulphates               0.020799
# alcohol                 0.114658
# quality                 0.407865
# dtype: float64

# %% [markdown]
# so here we can see skewness is almost removed from every column.

# %% [markdown]
# ## Converting target variable into categorical column

# %% [markdown]
# =7 or higher getting classified as 'good/1 and the remainder as 'not good/0

# %%
(df['quality']<7).value_counts()
# Out:
# True     1250
# False     201
# Name: quality, dtype: int64

# %%
(df['quality']>=7).value_counts()
# Out:
# False    1250
# True      201
# Name: quality, dtype: int64

# %%
df.loc[(df['quality'] < 7.0),'quality']=0.0
df.loc[(df['quality'] >=7.0),'quality']=1

# %%
print(df.quality.value_counts())
sns.countplot(df['quality'])
# Out:
# 0    1250
# 1     201
# Name: quality, dtype: int64
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %% [markdown]
# Here we can see our target variable(quality) converted into two categories 0 & 1
#
# here we can see the countplot of it according to count, the data is imbalance(we have to deal with it)

# %% [markdown]
# ## Dividing Data into X and Y

# %%
x=df.drop(['quality'],axis=1)
y=df['quality']

# %%
x.shape
# Out:
# (1451, 11)

# %%
y.shape
# Out:
# (1451,)

# %% [markdown]
# ## Imbalanced learn

# %% [markdown]
# using RandomOverSampler because there is very less data

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
ros= RandomOverSampler(random_state=42)
x_ros, y_ros = ros.fit_resample(x,y)
print('original Target dataset shape:', y.shape)
print('Resample Target dataset shape', y_ros.shape)
# Out:
# original Target dataset shape: (1451,)
# Resample Target dataset shape (2500,)

# %%
x_ros.shape
# Out:
# (2500, 11)

# %%
y_ros.value_counts()
# Out:
# 0    1250
# 1    1250
# Name: quality, dtype: int64

# %% [markdown]
# Here we can see target variable in balanced now.

# %% [markdown]
# ## Spliting train and Test Data

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test= train_test_split(x_ros,y_ros,test_size=.23,random_state=42)

# %%
x_train.shape
# Out:
# (1925, 11)

# %%
x_test.shape
# Out:
# (575, 11)

# %%
y_train.shape
# Out:
# (1925,)

# %%
y_test.shape
# Out:
# (575,)

# %% [markdown]
# ## Model Building

# %%
from sklearn.linear_model import LogisticRegression

from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier

from sklearn.model_selection import GridSearchCV
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score


import warnings
from sklearn.model_selection import cross_val_score
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Logistic Regression

# %%
logreg=LogisticRegression()
logreg_score=cross_val_score(logreg,x_ros,y_ros,cv=5,scoring='accuracy')
print('cross validation score for svm:',np.mean(logreg_score))
# Out:
# cross validation score for svm: 0.7856

# %%
logreg.fit(x_train,y_train)
LR_predicted=logreg.predict(x_test)

print(accuracy_score(y_test,LR_predicted))
print(confusion_matrix(y_test,LR_predicted))
print(classification_report(y_test,LR_predicted))
print("Training accuracy::",logreg.score(x_train,y_train))
print("Test accuracy::",logreg.score(x_test,y_test))
# Out:
# 0.7895652173913044
# [[215  66]
#  [ 55 239]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.77      0.78       281
#            1       0.78      0.81      0.80       294
#
#     accuracy                           0.79       575
#    macro avg       0.79      0.79      0.79       575
# weighted avg       0.79      0.79      0.79       575
#
# Training accuracy:: 0.8051948051948052
# Test accuracy:: 0.7895652173913044

# %% [markdown]
# ### Decision Tree Classifier

# %%
dtc=DecisionTreeClassifier()
dtc_score=cross_val_score(dtc,x_ros,y_ros,cv=5,scoring='accuracy')
print("cross validation score for svm:",np.mean(dtc_score))
# Out:
# cross validation score for svm: 0.9352

# %%
dtc.fit(x_train,y_train)
predicted_dtc=dtc.predict(x_test)

print(accuracy_score(y_test,predicted_dtc))
print(confusion_matrix(y_test,predicted_dtc))
print(classification_report(y_test,predicted_dtc))
print("Training accuracy::",dtc.score(x_train,y_train))
print("Test accuracy::",dtc.score(x_test,y_test))
# Out:
# 0.9652173913043478
# [[262  19]
#  [  1 293]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.93      0.96       281
#            1       0.94      1.00      0.97       294
#
#     accuracy                           0.97       575
#    macro avg       0.97      0.96      0.97       575
# weighted avg       0.97      0.97      0.97       575
#
# Training accuracy:: 1.0
# Test accuracy:: 0.9652173913043478

# %% [markdown]
# ### KNeighbours Classifier

# %%
knn=KNeighborsClassifier()
knn_score=cross_val_score(knn,x_ros,y_ros,cv=5,scoring='accuracy')
print("cross validation score for knn:",np.mean(knn_score))
# Out:
# cross validation score for knn: 0.86

# %%
knn.fit(x_train,y_train)
predicted_knn=knn.predict(x_test)

print(accuracy_score(y_test,predicted_knn))
print(confusion_matrix(y_test,predicted_knn))
print(classification_report(y_test,predicted_knn))
print("Training accuracy::",knn.score(x_train,y_train))
print("Test accuracy::",knn.score(x_test,y_test))
# Out:
# 0.8939130434782608
# [[223  58]
#  [  3 291]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.79      0.88       281
#            1       0.83      0.99      0.91       294
#
#     accuracy                           0.89       575
#    macro avg       0.91      0.89      0.89       575
# weighted avg       0.91      0.89      0.89       575
#
# Training accuracy:: 0.9205194805194805
# Test accuracy:: 0.8939130434782608

# %% [markdown]
# ### RandomForestClassifier

# %%
rfc=RandomForestClassifier()
rfc_score=cross_val_score(rfc,x_ros,y_ros,cv=5,scoring='accuracy')
print("cross validation score for rfc:",np.mean(rfc_score))
# Out:
# cross validation score for rfc: 0.9548

# %%
rfc.fit(x_train,y_train)
predicted_rfc=rfc.predict(x_test)

print(accuracy_score(y_test,predicted_rfc))
print(confusion_matrix(y_test,predicted_rfc))
print(classification_report(y_test,predicted_rfc))
print("Training accuracy::",rfc.score(x_train,y_train))
print("Test accuracy::",rfc.score(x_test,y_test))
# Out:
# 0.9773913043478261
# [[268  13]
#  [  0 294]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.98       281
#            1       0.96      1.00      0.98       294
#
#     accuracy                           0.98       575
#    macro avg       0.98      0.98      0.98       575
# weighted avg       0.98      0.98      0.98       575
#
# Training accuracy:: 1.0
# Test accuracy:: 0.9773913043478261

# %% [markdown]
# ## Ensemble Technique

# %% [markdown]
# ### 1. Ada Boost Classifier

# %%
adb=AdaBoostClassifier()
adb_score=cross_val_score(adb,x_ros,y_ros,cv=10,scoring='accuracy')
print("cross validation score for Ada Boost :",np.mean(adb_score))
# Out:
# cross validation score for Ada Boost : 0.8560000000000001

# %%
adb.fit(x_train,y_train)
predicted_adb=adb.predict(x_test)

print(accuracy_score(y_test,predicted_adb))
print(confusion_matrix(y_test,predicted_adb))
print(classification_report(y_test,predicted_adb))
print("Training accuracy::",adb.score(x_train,y_train))
print("Test accuracy::",adb.score(x_test,y_test))
# Out:
# 0.8556521739130435
# [[233  48]
#  [ 35 259]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.83      0.85       281
#            1       0.84      0.88      0.86       294
#
#     accuracy                           0.86       575
#    macro avg       0.86      0.86      0.86       575
# weighted avg       0.86      0.86      0.86       575
#
# Training accuracy:: 0.8914285714285715
# Test accuracy:: 0.8556521739130435

# %% [markdown]
# ### 2. Bagging Classifier

# %%
bgc=BaggingClassifier()
bgc_score=cross_val_score(bgc,x_ros,y_ros,cv=10,scoring='accuracy')
print("cross validation score for Bagging Classifier:",np.mean(bgc_score))
# Out:
# cross validation score for Bagging Classifier: 0.9603999999999999

# %%
bgc.fit(x_train,y_train)
predicted_bgc=bgc.predict(x_test)

print(accuracy_score(y_test,predicted_bgc))
print(confusion_matrix(y_test,predicted_bgc))
print(classification_report(y_test,predicted_bgc))
print("Training accuracy::",bgc.score(x_train,y_train))
print("Test accuracy::",bgc.score(x_test,y_test))
# Out:
# 0.9686956521739131
# [[263  18]
#  [  0 294]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97       281
#            1       0.94      1.00      0.97       294
#
#     accuracy                           0.97       575
#    macro avg       0.97      0.97      0.97       575
# weighted avg       0.97      0.97      0.97       575
#
# Training accuracy:: 1.0
# Test accuracy:: 0.9686956521739131

# %% [markdown]
# so here we can choose Bagging Classifier as final model for Hyper Parameter tuning ,
#
# because there both train and test accuracies are highest and pretty close.
#
# rest Ada Boost classifier model having huge difference between train and test accuracies so not considering it.

# %% [markdown]
# ## Hyper Parameter Tuning

# %%
bgc=BaggingClassifier()
param_grid={
    'n_estimators':[100,200],
    'max_features':[1,2]
}

# %%
bgc_grid=GridSearchCV(BaggingClassifier(),param_grid,cv=10,scoring='accuracy',n_jobs=-1,verbose=2)

# %%
bgc_grid.fit(x_train,y_train)
bgc_pred=bgc_grid.best_estimator_.predict(x_test)
print("Accuracy after parameter tuning::",accuracy_score(y_test,bgc_pred))
# Out:
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# Accuracy after parameter tuning:: 0.9947826086956522

# %% [markdown]
# As we can notice after HYPER PARAMETER TUNING with the models accuracy score got increased.

# %% [markdown]
# ## Report of Bagging Classifier

# %%
print("CLASSIFICATION REPORT::\n", classification_report(y_test,bgc_pred))
# Out:
# CLASSIFICATION REPORT::
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99       281
#            1       0.99      1.00      0.99       294
#
#     accuracy                           0.99       575
#    macro avg       0.99      0.99      0.99       575
# weighted avg       0.99      0.99      0.99       575

# %%
clsf_repo=classification_report(y_test,bgc_pred,output_dict=True)
sns.heatmap(pd.DataFrame(clsf_repo).T, annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import roc_auc_score

# %%
print("roc auc score::",roc_auc_score(y_test,bgc_pred))
# Out:
# roc auc score:: 0.9946619217081851

# %%
from sklearn.metrics import roc_curve

# %%
fpr1, tpr1, thresh1 = roc_curve(y_test, bgc_pred,pos_label=1)

# %%
# plotting ROC CURVE
sns.set_theme(style='darkgrid')
plt.plot(fpr1, tpr1, linestyle=':',color='red', label='BaggingClassifier')

plt.title('ROC CURVE')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='best')

# %% [markdown]
# ## Saving The Model

# %%
import joblib
joblib.dump(bgc_grid.best_estimator_,'Red_wine_Quality_PRoject.obj')
# Out:
# ['Red_wine_Quality_PRoject.obj']
